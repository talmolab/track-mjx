# %% [markdown]
# # Explore Rodent Reference Clips
#
# This notebook explores the structure of the rodent reference clips h5 file.

# %%
import h5py
import yaml
import numpy as np

# %%
# Path to the reference clips file
h5_path = "data/rodent/rodent_reference_clips.h5"

# %%
def print_h5_structure(h5_file, indent=0):
    """Recursively print the structure of an h5 file."""
    for key in h5_file.keys():
        item = h5_file[key]
        prefix = "  " * indent
        if isinstance(item, h5py.Group):
            print(f"{prefix}{key}/ (Group)")
            print_h5_structure(item, indent + 1)
        elif isinstance(item, h5py.Dataset):
            print(f"{prefix}{key}: shape={item.shape}, dtype={item.dtype}")
        else:
            print(f"{prefix}{key}: {type(item)}")

# %%
# Open and explore the h5 file
with h5py.File(h5_path, "r") as fid:
    print("=" * 60)
    print("H5 FILE STRUCTURE")
    print("=" * 60)
    print_h5_structure(fid)
    print()
# Out:
# ============================================================
# H5 FILE STRUCTURE
# ============================================================
# config: shape=(), dtype=object
# kp_data: shape=(210500, 69), dtype=float64
# kp_names: shape=(23,), dtype=|S9
# marker_sites: shape=(210500, 23, 3), dtype=float32
# names_qpos: shape=(74,), dtype=|S26
# names_xpos: shape=(67,), dtype=|S19
# offsets: shape=(23, 3), dtype=float32
# qpos: shape=(210500, 74), dtype=float32
# qvel: shape=(210500, 73), dtype=float32
# xpos: shape=(210500, 67, 3), dtype=float32
# xquat: shape=(210500, 67, 4), dtype=float32

# %%
# Load and parse the config
with h5py.File(h5_path, "r") as fid:
    config = yaml.safe_load(fid["config"][()])
    
print("=" * 60)
print("CONFIG")
print("=" * 60)
for key, value in config.items():
    if isinstance(value, dict):
        print(f"{key}:")
        for k, v in value.items():
            if isinstance(v, list) and len(v) > 5:
                print(f"  {k}: [{len(v)} items]")
            else:
                print(f"  {k}: {v}")
    else:
        print(f"{key}: {value}")
# Out:
# ============================================================
# CONFIG
# ============================================================
# model:
#   FTOL: 0.005
#   INDIVIDUAL_PART_OPTIMIZATION: {'head': ['atlas', 'cervical', 'atlant_extend'], 'l_arm': ['scapula_L', 'shoulder_L', 'elbow_L', 'hand_L', 'finger_L'], 'l_leg': ['vertebra_1', 'vertebra_2', 'vertebra_3', 'vertebra_4', 'vertebra_5', 'vertebra_6', 'hip_L', 'knee_L', 'ankle_L', 'foot_L'], 'r_arm': ['scapula_R', 'shoulder_R', 'elbow_R', 'hand_R', 'finger_R'], 'r_leg': ['vertebra_1', 'vertebra_2', 'vertebra_3', 'vertebra_4', 'vertebra_5', 'vertebra_6', 'hip_R', 'knee_R', 'ankle_R', 'foot_R']}
#   KEYPOINT_COLOR_PAIRS: {'AnkleL': '0 0 .3 1', 'AnkleR': '.3 0 0 1', 'EarL': '0 0 .8 1', 'EarR': '.8 0 0 1', 'ElbowL': '0 0 .8 1', 'ElbowR': '.8 0 0 1', 'FootL': '0 0 .3 1', 'FootR': '.3 0 0 1', 'HandL': '0 0 .8 1', 'HandR': '.8 0 0 1', 'HipL': '0 0 .3 1', 'HipR': '.3 0 0 1', 'KneeL': '0 0 .3 1', 'KneeR': '.3 0 0 1', 'ShoulderL': '0 0 .8 1', 'ShoulderR': '.8 0 0 1', 'Snout': '.8 .8 .8 1', 'SpineF': '.8 .8 .8 1', 'SpineL': '.8 .8 .8 1', 'SpineM': '.8 .8 .8 1', 'TailBase': '.8 .8 .8 1', 'WristL': '0 0 .8 1', 'WristR': '.8 0 0 1'}
#   KEYPOINT_INITIAL_OFFSETS: {'AnkleL': '-0.03230154033783406 -0.004727054683585472 -0.02205958852339887', 'AnkleR': '-0.03230154033783406 0.004727054683585472 -0.02205958852339887', 'EarL': '0. 0. 0.', 'EarR': '0. 0. 0.', 'ElbowL': '-0.01593120836133218 0.01035528543486592 -0.02230369170586505', 'ElbowR': '-0.01593120836133218 -0.01035528543486592 -0.02230369170586505', 'FootL': '0.02109994311367263 0.007614327297542731 -0.002752166493087734', 'FootR': '0.02109994311367263 -0.007614327297542731 -0.002752166493087734', 'HandL': '0.003031746915839468 0.001515873457919734 -0.008337304018558537', 'HandR': '0.003031746915839468 -0.001515873457919734 -0.008337304018558537', 'HipL': '-0.015 0.015 0.', 'HipR': '-0.015 -0.015 0.', 'KneeL': '0.01542264534586861 0.01747899805865108 -0.02570440890978101', 'KneeR': '0.01542264534586861 -0.01747899805865108 -0.02570440890978101', 'ShoulderL': '0.0287 0.00984 -0.02542', 'ShoulderR': '0.0287 -0.00984 -0.02542', 'Snout': '0. 0. 0.', 'SpineF': '-0.015 0. 0.0', 'SpineL': '0. 0. 0.0', 'SpineM': '0. 0. 0.0', 'TailBase': '0. 0. 0.', 'WristL': '0. 0. 0.0', 'WristR': '0. 0. 0.0'}
#   KEYPOINT_MODEL_PAIRS: {'AnkleL': 'lower_leg_L', 'AnkleR': 'lower_leg_R', 'EarL': 'skull', 'EarR': 'skull', 'ElbowL': 'upper_arm_L', 'ElbowR': 'upper_arm_R', 'FootL': 'foot_L', 'FootR': 'foot_R', 'HandL': 'hand_L', 'HandR': 'hand_R', 'HipL': 'pelvis', 'HipR': 'pelvis', 'KneeL': 'upper_leg_L', 'KneeR': 'upper_leg_R', 'ShoulderL': 'scapula_L', 'ShoulderR': 'scapula_R', 'Snout': 'skull', 'SpineF': 'vertebra_cervical_5', 'SpineL': 'pelvis', 'SpineM': 'vertebra_1', 'TailBase': 'pelvis', 'WristL': 'lower_arm_L', 'WristR': 'lower_arm_R'}
#   KP_NAMES: [23 items]
#   LIMB_FTOL: 1e-06
#   MJCF_PATH: models/rodent.xml
#   MOCAP_SCALE_FACTOR: 0.001
#   M_REG_COEF: 1
#   N_ITERS: 6
#   N_SAMPLE_FRAMES: 100
#   RENDER_FPS: 50
#   ROOT_FTOL: 1e-05
#   ROOT_OPTIMIZATION_KEYPOINT: SpineL
#   SCALE_FACTOR: 0.9
#   SITES_TO_REGULARIZE: ['HandL', 'HandR', 'SpineF', 'SpineL', 'SpineM']
#   TRUNK_OPTIMIZATION_KEYPOINTS: [8 items]
#   snips_order: [842 items]
# stac:
#   data_path: /n/holylabs/LABS/olveczky_lab/holylfs02/Everyone/dannce_rig/dannce_ephys/coltrane/2021_07_28_1/DANNCE/predict00/save_data_AVG.mat
#   fit_offsets_path: fit_snips.h5
#   ik_only_path: transform_snips.h5
#   infer_qvels: True
#   mujoco: {'iterations': 1, 'ls_iterations': 4, 'solver': 'newton'}
#   n_fit_frames: 250
#   n_frames_per_clip: 250
#   skip_fit_offsets: False
#   skip_ik_only: False

# %%
# Calculate number of clips
with h5py.File(h5_path, "r") as fid:
    qpos_shape = fid["qpos"].shape
    qvel_shape = fid["qvel"].shape
    xpos_shape = fid["xpos"].shape
    xquat_shape = fid["xquat"].shape
    
    # Get clip length from config
    config = yaml.safe_load(fid["config"][()])
    
    # Names
    names_qpos = fid["names_qpos"][()].astype(str)
    names_xpos = fid["names_xpos"][()].astype(str)

print("\n" + "=" * 60)
print("DATA ARRAYS")
print("=" * 60)
print(f"qpos shape: {qpos_shape}")
print(f"qvel shape: {qvel_shape}")
print(f"xpos shape: {xpos_shape}")
print(f"xquat shape: {xquat_shape}")

print(f"\nnames_qpos ({len(names_qpos)} entries): {list(names_qpos)}")
print(f"\nnames_xpos ({len(names_xpos)} entries): {list(names_xpos)}")
# Out:
# ============================================================
# DATA ARRAYS
# ============================================================
# qpos shape: (210500, 74)
# qvel shape: (210500, 73)
# xpos shape: (210500, 67, 3)
# xquat shape: (210500, 67, 4)
#
# names_qpos (74 entries): [np.str_('root'), np.str_('root'), np.str_('root'), np.str_('root'), np.str_('root'), np.str_('root'), np.str_('root'), np.str_('vertebra_1_extend'), np.str_('vertebra_2_bend'), np.str_('vertebra_3_twist'), np.str_('vertebra_4_extend'), np.str_('vertebra_5_bend'), np.str_('vertebra_6_twist'), np.str_('hip_L_supinate'), np.str_('hip_L_abduct'), np.str_('hip_L_extend'), np.str_('knee_L'), np.str_('ankle_L'), np.str_('toe_L'), np.str_('hip_R_supinate'), np.str_('hip_R_abduct'), np.str_('hip_R_extend'), np.str_('knee_R'), np.str_('ankle_R'), np.str_('toe_R'), np.str_('vertebra_C1_extend'), np.str_('vertebra_C1_bend'), np.str_('vertebra_C2_extend'), np.str_('vertebra_C2_bend'), np.str_('vertebra_C3_extend'), np.str_('vertebra_C3_bend'), np.str_('vertebra_C4_extend'), np.str_('vertebra_C4_bend'), np.str_('vertebra_C5_extend'), np.str_('vertebra_C5_bend'), np.str_('vertebra_C6_extend'), np.str_('vertebra_C6_bend'), np.str_('vertebra_C7_extend'), np.str_('vertebra_C9_bend'), np.str_('vertebra_C11_extend'), np.str_('vertebra_C13_bend'), np.str_('vertebra_C15_extend'), np.str_('vertebra_C17_bend'), np.str_('vertebra_C19_extend'), np.str_('vertebra_C21_bend'), np.str_('vertebra_C23_extend'), np.str_('vertebra_C25_bend'), np.str_('vertebra_C27_extend'), np.str_('vertebra_C29_bend'), np.str_('vertebra_cervical_5_extend'), np.str_('vertebra_cervical_4_bend'), np.str_('vertebra_cervical_3_twist'), np.str_('vertebra_cervical_2_extend'), np.str_('vertebra_cervical_1_bend'), np.str_('vertebra_axis_twist'), np.str_('vertebra_atlant_extend'), np.str_('atlas'), np.str_('mandible'), np.str_('scapula_L_supinate'), np.str_('scapula_L_abduct'), np.str_('scapula_L_extend'), np.str_('shoulder_L'), np.str_('shoulder_sup_L'), np.str_('elbow_L'), np.str_('wrist_L'), np.str_('finger_L'), np.str_('scapula_R_supinate'), np.str_('scapula_R_abduct'), np.str_('scapula_R_extend'), np.str_('shoulder_R'), np.str_('shoulder_sup_R'), np.str_('elbow_R'), np.str_('wrist_R'), np.str_('finger_R')]
#
# names_xpos (67 entries): [np.str_('world'), np.str_('walker'), np.str_('torso'), np.str_('vertebra_1'), np.str_('vertebra_2'), np.str_('vertebra_3'), np.str_('vertebra_4'), np.str_('vertebra_5'), np.str_('vertebra_6'), np.str_('pelvis'), np.str_('upper_leg_L'), np.str_('lower_leg_L'), np.str_('foot_L'), np.str_('toe_L'), np.str_('upper_leg_R'), np.str_('lower_leg_R'), np.str_('foot_R'), np.str_('toe_R'), np.str_('vertebra_C1'), np.str_('vertebra_C2'), np.str_('vertebra_C3'), np.str_('vertebra_C4'), np.str_('vertebra_C5'), np.str_('vertebra_C6'), np.str_('vertebra_C7'), np.str_('vertebra_C8'), np.str_('vertebra_C9'), np.str_('vertebra_C10'), np.str_('vertebra_C11'), np.str_('vertebra_C12'), np.str_('vertebra_C13'), np.str_('vertebra_C14'), np.str_('vertebra_C15'), np.str_('vertebra_C16'), np.str_('vertebra_C17'), np.str_('vertebra_C18'), np.str_('vertebra_C19'), np.str_('vertebra_C20'), np.str_('vertebra_C21'), np.str_('vertebra_C22'), np.str_('vertebra_C23'), np.str_('vertebra_C24'), np.str_('vertebra_C25'), np.str_('vertebra_C26'), np.str_('vertebra_C27'), np.str_('vertebra_C28'), np.str_('vertebra_C29'), np.str_('vertebra_C30'), np.str_('vertebra_cervical_5'), np.str_('vertebra_cervical_4'), np.str_('vertebra_cervical_3'), np.str_('vertebra_cervical_2'), np.str_('vertebra_cervical_1'), np.str_('vertebra_axis'), np.str_('vertebra_atlant'), np.str_('skull'), np.str_('jaw'), np.str_('scapula_L'), np.str_('upper_arm_L'), np.str_('lower_arm_L'), np.str_('hand_L'), np.str_('finger_L'), np.str_('scapula_R'), np.str_('upper_arm_R'), np.str_('lower_arm_R'), np.str_('hand_R'), np.str_('finger_R')]

# %%
# Calculate number of clips based on standard clip length
# The default clip_length in the imitation config is 250 frames
CLIP_LENGTH = 250

total_frames = qpos_shape[0]
n_clips = total_frames // CLIP_LENGTH

print("\n" + "=" * 60)
print("CLIP INFORMATION")
print("=" * 60)
print(f"Total frames: {total_frames}")
print(f"Clip length: {CLIP_LENGTH} frames")
print(f"Number of clips: {n_clips}")

# Verify with config snips_order if available
if "model" in config and "snips_order" in config["model"]:
    snips_order = config["model"]["snips_order"]
    print(f"\nClips from config (snips_order): {len(snips_order)} clips")
    print(f"Clip names (first 10): {snips_order[:10]}")
    if len(snips_order) > 10:
        print(f"... and {len(snips_order) - 10} more")
# Out:
# ============================================================
# CLIP INFORMATION
# ============================================================
# Total frames: 210500
# Clip length: 250 frames
# Number of clips: 842
#
# Clips from config (snips_order): 842 clips
# Clip names (first 10): ['RGroom_4', 'Rear_149', 'Walk_174', 'FaceGroom_0', 'LGroom_48', 'FaceGroom_143', 'FaceGroom_82', 'LGroom_51', 'Walk_182', 'FaceGroom_142']
# ... and 832 more

# %%
# Show behavior types if available
import re

if "model" in config and "snips_order" in config["model"]:
    pattern = r"([A-Za-z]+)_\d+(\.p)?"
    behavior_counts = {}
    for fn in config["model"]["snips_order"]:
        m = re.search(pattern, fn)
        if m:
            behavior = m.group(1)
            behavior_counts[behavior] = behavior_counts.get(behavior, 0) + 1
    
    print("\n" + "=" * 60)
    print("BEHAVIOR TYPES")
    print("=" * 60)
    for behavior, count in sorted(behavior_counts.items(), key=lambda x: -x[1]):
        print(f"  {behavior}: {count} clips")
# Out:
# ============================================================
# BEHAVIOR TYPES
# ============================================================
#   FastWalk: 189 clips
#   Walk: 174 clips
#   Rear: 165 clips
#   FaceGroom: 136 clips
#   RGroom: 96 clips
#   LGroom: 82 clips
